# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:/Users/u s e r/Desktop/realtor-data.zip.csv")

# %%
df
# Out:
#          brokered_by    status     price  bed  bath  acre_lot     street  \
# 0           103378.0  for_sale  105000.0  3.0   2.0      0.12  1962661.0
# 1            52707.0  for_sale   80000.0  4.0   2.0      0.08  1902874.0
# 2           103379.0  for_sale   67000.0  2.0   1.0      0.15  1404990.0
# 3            31239.0  for_sale  145000.0  4.0   2.0      0.10  1947675.0
# 4            34632.0  for_sale   65000.0  6.0   2.0      0.05   331151.0
# ...              ...       ...       ...  ...   ...       ...        ...
# 2226377      23009.0      sold  359900.0  4.0   2.0      0.33   353094.0
# 2226378      18208.0      sold  350000.0  3.0   2.0      0.10  1062149.0
# 2226379      76856.0      sold  440000.0  6.0   3.0      0.50   405677.0
# 2226380      53618.0      sold  179900.0  2.0   1.0      0.09   761379.0
# 2226381     108243.0      sold  580000.0  5.0   3.0      0.31   307704.0
#
#                city        state  zip_code  house_size prev_sold_date
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2226382 entries, 0 to 2226381
# Data columns (total 12 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   brokered_by     float64
#  1   status          object
#  2   price           float64
#  3   bed             float64
#  4   bath            float64
#  5   acre_lot        float64
#  6   street          float64
#  7   city            object
#  8   state           object
#  9   zip_code        float64
#  10  house_size      float64
#  11  prev_sold_date  object
# dtypes: float64(8), object(4)
# memory usage: 203.8+ MB

# %%
df.describe()
# Out:
#         brokered_by         price           bed          bath      acre_lot  \
# count  2.221849e+06  2.224841e+06  1.745065e+06  1.714611e+06  1.900793e+06
# mean   5.293989e+04  5.241955e+05  3.275841e+00  2.496440e+00  1.522303e+01
# std    3.064275e+04  2.138893e+06  1.567274e+00  1.652573e+00  7.628238e+02
# min    0.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    2.386100e+04  1.650000e+05  3.000000e+00  2.000000e+00  1.500000e-01
# 50%    5.288400e+04  3.250000e+05  3.000000e+00  2.000000e+00  2.600000e-01
# 75%    7.918300e+04  5.500000e+05  4.000000e+00  3.000000e+00  9.800000e-01
# max    1.101420e+05  2.147484e+09  4.730000e+02  8.300000e+02  1.000000e+05
#
#              street      zip_code    house_size
# count  2.215516e+06  2.226083e+06  1.657898e+06
# mean   1.012325e+06  5.218668e+04  2.714471e+03
# std    5.837635e+05  2.895408e+04  8.081635e+05
# min    0.000000e+00  0.000000e+00  4.000000e+00
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df.drop(columns=['brokered_by','street'],inplace=True)

# %%
df.head()
# Out:
#      status     price  bed  bath  acre_lot        city        state  zip_code  \
# 0  for_sale  105000.0  3.0   2.0      0.12    Adjuntas  Puerto Rico     601.0
# 1  for_sale   80000.0  4.0   2.0      0.08    Adjuntas  Puerto Rico     601.0
# 2  for_sale   67000.0  2.0   1.0      0.15  Juana Diaz  Puerto Rico     795.0
# 3  for_sale  145000.0  4.0   2.0      0.10       Ponce  Puerto Rico     731.0
# 4  for_sale   65000.0  6.0   2.0      0.05    Mayaguez  Puerto Rico     680.0
#
#    house_size prev_sold_date
# 0       920.0            NaN
# 1      1527.0            NaN
# 2       748.0            NaN
# 3      1800.0            NaN
# 4         NaN            NaN

# %%
df.isna().sum()
# Out:
# status                 0
# price               1541
# bed               481317
# bath              511771
# acre_lot          325589
# city                1407
# state                  8
# zip_code             299
# house_size        568484
# prev_sold_date    734297
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# status            0
# price             0
# bed               0
# bath              0
# acre_lot          0
# city              0
# state             0
# zip_code          0
# house_size        0
# prev_sold_date    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1273)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#            status      price  bed  bath  acre_lot          city  \
# 502      for_sale   110000.0  7.0   3.0      0.09        Dorado
# 2270     for_sale   950000.0  5.0   4.0      0.99  Saint Thomas
# 2277     for_sale  6899000.0  4.0   6.0      0.83  Saint Thomas
# 3409     for_sale   525000.0  3.0   3.0      0.45        Agawam
# 3410     for_sale   289900.0  3.0   2.0      0.36        Agawam
# ...           ...        ...  ...   ...       ...           ...
# 2226377      sold   359900.0  4.0   2.0      0.33      Richland
# 2226378      sold   350000.0  3.0   2.0      0.10      Richland
# 2226379      sold   440000.0  6.0   3.0      0.50      Richland
# 2226380      sold   179900.0  2.0   1.0      0.09      Richland
# 2226381      sold   580000.0  5.0   3.0      0.31      Richland
#
#                   state  zip_code  house_size prev_sold_date
# 502         Puerto Rico     949.0      1192.0     2019-06-28
# 2270     Virgin Islands     802.0      5000.0     2013-10-11
# ...

# %%
num_features = ['price', 'house_size', 'acre_lot', 'bed', 'bath']

def remove_outliers_zscore(df, column, threshold=3):
    z_scores = (df[column] - df[column].mean()) / df[column].std()
    df_clean = df[np.abs(z_scores) <= threshold]
    print(f"{column}: removed {df.shape[0] - df_clean.shape[0]} outliers")
    return df_clean

# نبدأ بالداتا الأصلية
newdf = df.copy()

# تنظيف تراكمي
for col in num_features:
    newdf = remove_outliers_zscore(newdf, col)

print("\n✅ Final dataset shape:", newdf.shape)
# Out:
# price: removed 7980 outliers
# house_size: removed 988 outliers
# acre_lot: removed 438 outliers
# bed: removed 5259 outliers
# bath: removed 13001 outliers
#
# ✅ Final dataset shape: (1060806, 10)

# %%
newdf
# Out:
#            status     price  bed  bath  acre_lot          city  \
# 502      for_sale  110000.0  7.0   3.0      0.09        Dorado
# 2270     for_sale  950000.0  5.0   4.0      0.99  Saint Thomas
# 3409     for_sale  525000.0  3.0   3.0      0.45        Agawam
# 3410     for_sale  289900.0  3.0   2.0      0.36        Agawam
# 3416     for_sale  384900.0  3.0   2.0      0.46        Agawam
# ...           ...       ...  ...   ...       ...           ...
# 2226377      sold  359900.0  4.0   2.0      0.33      Richland
# 2226378      sold  350000.0  3.0   2.0      0.10      Richland
# 2226379      sold  440000.0  6.0   3.0      0.50      Richland
# 2226380      sold  179900.0  2.0   1.0      0.09      Richland
# 2226381      sold  580000.0  5.0   3.0      0.31      Richland
#
#                   state  zip_code  house_size prev_sold_date
# 502         Puerto Rico     949.0      1192.0     2019-06-28
# 2270     Virgin Islands     802.0      5000.0     2013-10-11
# ...

# %%
# convert zip_code to string
newdf['zip_code'] = newdf['zip_code'].astype(str)

# %%
newdf['zip_code']
# Out:
# 502          949.0
# 2270         802.0
# 3409        1001.0
# 3410        1001.0
# 3416        1001.0
#             ...
# 2226377    99354.0
# 2226378    99354.0
# 2226379    99354.0
# 2226380    99354.0
# 2226381    99354.0
# Name: zip_code, Length: 1060806, dtype: object

# %%
plt.hist(newdf['price'], bins=30)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribution of House Prices')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Apply log transform to price (add 1 to avoid log(0))
df['log_price'] = np.log1p(df['price'])

plt.figure(figsize=(8,5))
sns.histplot(df['log_price'], bins=50, kde=True)
plt.title("Log-Transformed Distribution of House Prices")
plt.xlabel("Log(Price + 1)")
plt.ylabel("Frequency")
plt.show()

# %%
# Average price per state
plt.figure(figsize=(12,6))
avg_price_state = df.groupby('state')['price'].mean().sort_values(ascending=False).head(20)  # نعرض Top 20 بس

sns.barplot(x=avg_price_state.index, y=avg_price_state.values)
plt.xticks(rotation=75)
plt.title("Average House Price per State (Top 20)")
plt.xlabel("State")
plt.ylabel("Average Price")
plt.show()

# %%
# Average price per city
plt.figure(figsize=(12,6))
avg_price_city = df.groupby('city')['price'].mean().sort_values(ascending=False).head(20)  # Top 20 مدن

sns.barplot(x=avg_price_city.index, y=avg_price_city.values)
plt.xticks(rotation=75)
plt.title("Average House Price per City (Top 20)")
plt.xlabel("City")
plt.ylabel("Average Price")
plt.show()

# %%
# نتأكد إن العمود تاريخ
df['prev_sold_date'] = pd.to_datetime(df['prev_sold_date'], errors='coerce')

# نطلع السنة بس
df['year_sold'] = df['prev_sold_date'].dt.year

# %%
# Plot number of houses sold per year
plt.figure(figsize=(10,5))
sales_per_year = df['year_sold'].value_counts().sort_index()

sns.lineplot(x=sales_per_year.index, y=sales_per_year.values, marker="o")
plt.title("Number of Houses Sold per Year")
plt.xlabel("Year")
plt.ylabel("Number of Houses Sold")
plt.show()

# %%
newdf
# Out:
#            status     price  bed  bath  acre_lot          city  \
# 502      for_sale  110000.0  7.0   3.0      0.09        Dorado
# 2270     for_sale  950000.0  5.0   4.0      0.99  Saint Thomas
# 3409     for_sale  525000.0  3.0   3.0      0.45        Agawam
# 3410     for_sale  289900.0  3.0   2.0      0.36        Agawam
# 3416     for_sale  384900.0  3.0   2.0      0.46        Agawam
# ...           ...       ...  ...   ...       ...           ...
# 2226377      sold  359900.0  4.0   2.0      0.33      Richland
# 2226378      sold  350000.0  3.0   2.0      0.10      Richland
# 2226379      sold  440000.0  6.0   3.0      0.50      Richland
# 2226380      sold  179900.0  2.0   1.0      0.09      Richland
# 2226381      sold  580000.0  5.0   3.0      0.31      Richland
#
#                   state zip_code  house_size prev_sold_date
# 502         Puerto Rico    949.0      1192.0     2019-06-28
# 2270     Virgin Islands    802.0      5000.0     2013-10-11
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
# Select features and target
features = ['house_size', 'acre_lot', 'bed', 'bath']
target = 'price' 
x=newdf[features]
y=newdf[target]
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("R^2 Score:", r2_score(y_test, y_pred))
# Out:
# Mean Squared Error: 143232407063.4978
# R^2 Score: 0.24216317275693366

# %%
df_corr = pd.concat([x, y], axis=1)

# نعمل correlation matrix
corr_matrix = df_corr.corr()


plt.figure(figsize=(6,4))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix (Features vs Price)")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

cat_columns = ["city", "state", "zip_code"]

for col in cat_columns:
    le = LabelEncoder()
    newdf[col] = le.fit_transform(newdf[col].astype(str))
 
x=newdf[features+cat_columns]
y=newdf[target]
print(newdf)
# Out:
#            status     price  bed  bath  acre_lot   city  state  zip_code  \
# 502      for_sale  110000.0  7.0   3.0      0.09  12046      5       583
# 2270     for_sale  950000.0  5.0   4.0      0.99  14422     18     14854
# 3409     for_sale  525000.0  3.0   3.0      0.45  10746     39      7889
# 3410     for_sale  289900.0  3.0   2.0      0.36  10746     39      7889
# 3416     for_sale  384900.0  3.0   2.0      0.46  10746     39      7889
# ...           ...       ...  ...   ...       ...    ...    ...       ...
# 2226377      sold  359900.0  4.0   2.0      0.33   5097     20      3231
# 2226378      sold  350000.0  3.0   2.0      0.10   5097     20      3231
# 2226379      sold  440000.0  6.0   3.0      0.50   5097     20      3231
# 2226380      sold  179900.0  2.0   1.0      0.09   5097     20      3231
# 2226381      sold  580000.0  5.0   3.0      0.31   5097     20      3231
#
#          house_size prev_sold_date
# 502          1192.0     2019-06-28
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)
rf_model=RandomForestRegressor(n_estimators=10, random_state=42)
rf_model.fit(x_train, y_train)
y_pred_rf = rf_model.predict(x_test) 
print("Random Forest Mean Squared Error:", mean_squared_error(y_test, y_pred_rf))
print("Random Forest R^2 Score:", r2_score(y_test, y_pred_rf))
# Out:
# Random Forest Mean Squared Error: 40045150804.24656
# Random Forest R^2 Score: 0.7881227394404773

# %%
cat_columns = ["city", "state", "zip_code"]

for col in cat_columns:
    le = LabelEncoder()
    newdf[col] = le.fit_transform(newdf[col].astype(str))

# %%
from catboost import CatBoostRegressor
cgmodel = CatBoostRegressor(iterations=15, learning_rate=0.1, depth=6, verbose=100)
cgmodel.fit(x_train, y_train)
y_pred_cb = cgmodel.predict(x_test)
print("CatBoost Mean Squared Error:", mean_squared_error(y_test, y_pred_cb))
print("CatBoost R^2 Score:", r2_score(y_test, y_pred_cb))
# Out:
# 0:	learn: 417755.2829036	total: 1.07s	remaining: 15s
# 14:	learn: 326219.6997526	total: 5.46s	remaining: 0us
# CatBoost Mean Squared Error: 106755300696.06207
# CatBoost R^2 Score: 0.43516205564417265

# %%
import lightgbm as lgb

x=newdf[features+cat_columns]
y=newdf[target]
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)
lgbmodel = lgb.LGBMRegressor(
    n_estimators=1000,
    learning_rate=0.05,
    num_leaves=31,
    max_depth=-1
)
lgbmodel.fit(x_train, y_train)
y_pred_lgb = lgbmodel.predict(x_test)
print("LightGBM Mean Squared Error:", mean_squared_error(y_test, y_pred_lgb))
print("LightGBM R^2 Score:", r2_score(y_test, y_pred_lgb))
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.055480 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1087
# [LightGBM] [Info] Number of data points in the train set: 848644, number of used features: 7
# [LightGBM] [Info] Start training from score 489900.957149
# LightGBM Mean Squared Error: 132410572438.8563
# LightGBM R^2 Score: 0.29942105862944945
